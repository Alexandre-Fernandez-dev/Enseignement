# %%
from sympy import *
from sympy import init_printing
from sympy import re, im, I, E, conjugate, symbols
from spb import plot, BB
init_printing()

# %%
x = symbols("x")
l = interpolate([(1, -1), (2, 0.5), (0, 0.5)], x)
l
# Out:
#      2
# 1.5⋅x  - 3.0⋅x + 0.5

# %%
d = diff(l)
d
# Out:
# 3.0⋅x - 3.0

# %%
def tangent(e, a):
    d = diff(e)
    return d.subs(x, a)*(x - a) + e.subs(x, a)

# %%
t_1 = tangent(l, 1)
t_2 = tangent(l, 2)

# %%
p1 = plot(l, t_1, t_2, xlim=(0,3), ylim=(-1.5,2), label=["$C_f$", "$T_1$", "$T_2$"], xlabel=" ", ylabel=" ", rendering_kw=[{"linestyle": "-"}], adaptive=False, is_point=False,axis_center="auto")

# %%
p1.save("functionA.png", dpi=200)

# %%
x = symbols("x")
l = interpolate([(1, 1), (2, -0), (0, -0)], x)
l
# Out:
#    2
# - x  + 2⋅x

# %%
d = diff(l)
d
# Out:
# 2 - 2⋅x

# %%
def tangent(e, a):
    d = diff(e)
    return d.subs(x, a)*(x - a) + e.subs(x, a)

# %%
t_1 = tangent(l, 1)
t_2 = tangent(l, 2)

# %%
p2 = plot(l, t_1, t_2, xlim=(0,3), ylim=(-1.5,2), label=["$C_f$", "$T_1$", "$T_2$"], xlabel=" ", ylabel=" ", rendering_kw=[{"linestyle": "-"}], adaptive=False, is_point=False,axis_center="auto")

# %%
p2.save("functionB.png", dpi=200)

# %%
x = symbols("x")
l = interpolate([(1, 1.5), (2.5, -0), (0.5, -0)], x)
l
# Out:
#        2
# - 2.0⋅x  + 6.0⋅x - 2.5

# %%
d = diff(l)
d
# Out:
# 6.0 - 4.0⋅x

# %%
def tangent(e, a):
    d = diff(e)
    return d.subs(x, a)*(x - a) + e.subs(x, a)

# %%
t_1 = tangent(l, 1.5)
t_2 = tangent(l, 2)

# %%
p3 = plot(l, t_1, t_2, xlim=(0,3), ylim=(-0.5,2.5), label=["$C_f$", "$T_1$", "$T_2$"], xlabel=" ", ylabel=" ", rendering_kw=[{"linestyle": "-"}], adaptive=False, is_point=False,axis_center="auto")

# %%
p3.save("functionC.png", dpi=200)

# %%
x = symbols("x")
l = interpolate([(1.5, 0.5), (2.5, 2.5), (0.5, 2.5)], x)
l
# Out:
#      2
# 2.0⋅x  - 6.0⋅x + 5.0

# %%
d = diff(l)
d
# Out:
# 4.0⋅x - 6.0

# %%
def tangent(e, a):
    d = diff(e)
    return d.subs(x, a)*(x - a) + e.subs(x, a)

# %%
t_1 = tangent(l, 1.5)
t_2 = tangent(l, 2)

# %%
p4 = plot(l, t_1, t_2, xlim=(0,3), ylim=(-0.5,2.5), label=["$C_f$", "$T_1$", "$T_2$"], xlabel=" ", ylabel=" ", rendering_kw=[{"linestyle": "-"}], adaptive=False, is_point=False,axis_center="auto")

# %%
p4.save("functionD.png", dpi=200)
