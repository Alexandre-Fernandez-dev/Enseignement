# %%
from sympy import *
from sympy import init_printing
from sympy import re, im, I, E, conjugate, symbols
from spb import plot, BB
init_printing()

# %%
x = symbols("x")
l = interpolate([(1, -1), (2, 1), (0, 1)], x)
l
# Out:
#    2
# 2⋅x  - 4⋅x + 1

# %%
d = diff(l)
d
# Out:
# 4⋅x - 4

# %%
def tangent(e, a):
    d = diff(e)
    return d.subs(x, a)*(x - a) + e.subs(x, a)

# %%
t_2 = tangent(l, 2)
#t_2 = tangent(l, 2)

# %%
p1 = plot(l, t_2, xlim=(0,3), ylim=(-1.5,2), label=["$C_f$", "$T_2$"], xlabel=" ", ylabel=" ", rendering_kw=[{"linestyle": "-"}], adaptive=False, is_point=False,axis_center="auto")

# %%
p1.save("functionA.png", dpi=200)

# %%
x = symbols("x")
l = interpolate([(1, 1.5), (2, -0.5), (0, -0.5)], x)
l
# Out:
#        2
# - 2.0⋅x  + 4.0⋅x - 0.5

# %%
d = diff(l)
d
# Out:
# 4.0 - 4.0⋅x

# %%
def tangent(e, a):
    d = diff(e)
    return d.subs(x, a)*(x - a) + e.subs(x, a)

# %%
t_2 = tangent(l, 2)
#t_2 = tangent(l, 2)

# %%
p2 = plot(l, t_2, xlim=(0,3), ylim=(-1.5,2), label=["$C_f$", "$T_2$"], xlabel=" ", ylabel=" ", rendering_kw=[{"linestyle": "-"}], adaptive=False, is_point=False,axis_center="auto")

# %%
p2.save("functionB.png", dpi=200)

# %%
x = symbols("x")
l = interpolate([(1, 1.5), (2.5, -0), (0.5, -0)], x)
l
# Out:
#        2
# - 2.0⋅x  + 6.0⋅x - 2.5

# %%
d = diff(l)
d
# Out:
# 6.0 - 4.0⋅x

# %%
def tangent(e, a):
    d = diff(e)
    return d.subs(x, a)*(x - a) + e.subs(x, a)

# %%
t_1 = tangent(l, 1.5)
t_2 = tangent(l, 2)

# %%
p3 = plot(l, t_1, t_2, xlim=(0,3), ylim=(-0.5,2.5), label=["$C_f$", "$T_1$", "$T_2$"], xlabel=" ", ylabel=" ", rendering_kw=[{"linestyle": "-"}], adaptive=False, is_point=False,axis_center="auto")

# %%
p3.save("functionC.png", dpi=200)

# %%
x = symbols("x")
l = interpolate([(1.5, 0.5), (2.5, 2.5), (0.5, 2.5)], x)
l
# Out:
#      2
# 2.0⋅x  - 6.0⋅x + 5.0

# %%
d = diff(l)
d
# Out:
# 4.0⋅x - 6.0

# %%
def tangent(e, a):
    d = diff(e)
    return d.subs(x, a)*(x - a) + e.subs(x, a)

# %%
t_1 = tangent(l, 1.5)
t_2 = tangent(l, 2)

# %%
p4 = plot(l, t_1, t_2, xlim=(0,3), ylim=(-0.5,2.5), label=["$C_f$", "$T_1$", "$T_2$"], xlabel=" ", ylabel=" ", rendering_kw=[{"linestyle": "-"}], adaptive=False, is_point=False,axis_center="auto")

# %%
p4.save("functionD.png", dpi=200)

# %%
x = symbols("x")

# %%
l=-2*x**2*(x-15)/100
l
latex(l)
# Out:
# '- \\frac{x^{2} \\left(x - 15\\right)}{50}'

# %%
p5 = plot(l, (x,0,15), xlim=(0,16), ylim=(0,11), label=["$C_f$"], xlabel="Temps (en jours)", ylabel="Malades (milliers)", rendering_kw=[{"linestyle": "-"}], adaptive=False, is_point=False,axis_center="auto")

# %%
p5.save("7A.png", dpi=200)

# %%
l = -3*x**2*(x-30)/400
l
print(latex(l))
# Out:
# - \frac{3 x^{2} \left(x - 30\right)}{400}

# %%
p6 = plot(l, (x,0,30), xlim=(0,32), ylim=(0,32), label=["$C_f$"], xlabel="Temps (en jours)", ylabel="Malades (milliers)", rendering_kw=[{"linestyle": "-"}], adaptive=False, is_point=False,axis_center="auto")

# %%
p6.save("7B.png", dpi=200)

# %%
x = symbols("x")
l = interpolate([(1, 0), (2, 1), (0, 1)], x)
l
# Out:
#  2
# x  - 2⋅x + 1

# %%
d = diff(l)
d
# Out:
# 2⋅x - 2

# %%
def tangent(e, a):
    d = diff(e)
    return d.subs(x, a)*(x - a) + e.subs(x, a)

# %%
t_2 = tangent(l, 2)
#t_2 = tangent(l, 2)

# %%
p1 = plot(l, t_2, xlim=(0,3), ylim=(-1.5,2), label=["$C_f$", "$T_2$"], xlabel=" ", ylabel=" ", rendering_kw=[{"linestyle": "-"}], adaptive=False, is_point=False,axis_center="auto")

# %%
p1.save("functionC.png", dpi=200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 p1.save("functionC.png", dpi=200)
#
# NameError: name 'p1' is not defined

# %%
x = symbols("x")
l = interpolate([(1, 2), (2, 1), (0, 1)], x)
l
# Out:
#    2
# - x  + 2⋅x + 1

# %%
d = diff(l)
d
# Out:
# 2 - 2⋅x

# %%
def tangent(e, a):
    d = diff(e)
    return d.subs(x, a)*(x - a) + e.subs(x, a)

# %%
t_2 = tangent(l, 2)
#t_2 = tangent(l, 2)

# %%
p1 = plot(l, t_2, xlim=(0,3), ylim=(-1.5,3), label=["$C_f$", "$T_2$"], xlabel=" ", ylabel=" ", rendering_kw=[{"linestyle": "-"}], adaptive=False, is_point=False,axis_center="auto")

# %%
p1.save("functionD.png", dpi=200)
