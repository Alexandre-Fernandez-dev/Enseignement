# %%
from sympy import *
from sympy import init_printing
from sympy import re, im, I, E, conjugate, symbols
from spb import plot, BB
init_printing()

# %%
x = symbols("x")
f = -4*(x-1)*(x-2)
expand(f)
# Out:
#      2
# - 4⋅x  + 12⋅x - 8

# %%
p = plot(f, xlim=(0,3), ylim=(-1,1.5), label=["f"], xlabel=" ", ylabel=" ", rendering_kw=[{"linestyle": "-"}], adaptive=False, is_point=False,axis_center="auto")

# %%
p.save("functionA.png", dpi=200)

# %%
g = 2*(x-1)*(x-3)
expand(g)
# Out:
#    2
# 2⋅x  - 8⋅x + 6

# %%
p2 = plot(g, xlim=(0,4), ylim=(-2.5,1), label=["f"], xlabel=" ", ylabel=" ", rendering_kw=[{"linestyle": "-"}], adaptive=False, is_point=False,axis_center="auto")

# %%
p2.save("functionB.png", dpi=200)

# %%
h = interpolate([(3, 0), (8, 0), (11/2, -1.5)], x)
h
# Out:
#       2
# 0.24⋅x  - 2.64⋅x + 5.76

# %%
p3 = plot(h, xlim=(0,9), ylim=(-2,1), label=["f"], xlabel=" ", ylabel=" ", rendering_kw=[{"linestyle": "-"}], adaptive=True, is_point=False,axis_center="auto")

# %%
p3.save("functionD.png", dpi=200)

# %%
l = interpolate([(0, 4), (3, 3), (-1, 3)], x)
l
# Out:
#    2
#   x    2⋅x
# - ── + ─── + 4
#   3     3

# %%
sujetc = interpolate([(0, 4), (1, 4), (-3, 10)], x)
sujetc
# Out:
#  2
# x    x
# ── - ─ + 4
# 2    2
